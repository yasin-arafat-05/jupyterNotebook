# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# <br>
# <br>
#
# # `#01 Confidence Interval: in tatanic dataset`
#
# <br>
# <br>

# %%
df = sns.load_dataset('titanic')
df.sample(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 798         0       3  male  30.0      0      0   7.2292        C  Third  man
# 248         1       1  male  37.0      1      1  52.5542        S  First  man
#
#      adult_male deck  embark_town alive  alone
# 798        True  NaN    Cherbourg    no   True
# 248        True    D  Southampton   yes  False

# %%
df["sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
sns.barplot(data=df,x="class",y="fare",hue="sex")
# Out:
# <Axes: xlabel='class', ylabel='fare'>
