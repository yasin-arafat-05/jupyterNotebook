# %% [markdown]
# ---
#
# <br>
#
# ---
#
# <br>
#
# ---
#
# <br>
# <br>
# <br>
#
# # `#1 :  Example of PDF in Data Science()`
#
# <br>
# <br>
# <br>
#
# ---
#
# <Br>
#
# ---
#
# <br>
#
# ---

# %%
import seaborn as sns

# %% [markdown]
# # `# 1.1 Example: ONE`

# %%
df = sns.load_dataset("iris")

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 11            4.8          3.4           1.6          0.2      setosa
# 148           6.2          3.4           5.4          2.3   virginica
# 100           6.3          3.3           6.0          2.5   virginica
# 124           6.7          3.3           5.7          2.1   virginica
# 71            6.1          2.8           4.0          1.3  versicolor

# %%
sns.kdeplot(data=df,x='petal_length',hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='sepal_length',hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='sepal_width',hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='petal_width',hue="species")
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# `যদি আমাকে বলা হয় যে, উপরের যেকোন দুইটা feature রাখতে পারবো । তাহলে, কোনটা রাখবো?? প্রথমঃ petal_width, দ্বিতীয়ঃ petal_length` এই দুইটা দিয়ে খুব সহজেই, Setosa কে আলাদা করা যাইতেছে । বাকি, দুইটার ক্ষেত্রেও সেম ।
#
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ---
#
# <br>
#
# ---
#
# <br>
#
# ---
#
# <br>
# <br>
# <br>
#
# # `#1 :  Example of CDF in Data Science()`
#
# <br>
# <br>
# <br>
#
# ---
#
# <Br>
#
# ---
#
# <br>
#
# ---

# %%
sns.kdeplot(data=df,x='petal_width',hue="species")
sns.ecdfplot(data=df,x="petal_width",hue="species")

# see pdf to uses of: ecdfplot()
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# <br>
# <br>
#
# # `#1.3: Joint Plot: `
#
# <br>
# <br>
