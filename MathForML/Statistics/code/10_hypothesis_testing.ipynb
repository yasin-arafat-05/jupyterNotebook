# %% [markdown]
# ### **Problem 1**
#
# A factory claims that the average lifetime of its bulbs is **1200 hours**.
# A random sample of **49 bulbs** shows a mean lifetime of **1160 hours**.
# The population standard deviation is known to be **140 hours**.
# Test the claim at **α = 0.05**.
#
#
# ### **Problem 2**
#
# Two machines produce the same type of component.
#
# * Machine A: n = 15, mean = 52, standard deviation = 4
# * Machine B: n = 12, mean = 48, standard deviation = 5
#
# At the **5% level of significance**, determine whether there is a difference in average output.
#
#
# ### **Problem 3**
#
# In a city, **420 out of 700 people** prefer electric buses.
# Test whether more than **55%** of the population prefers electric buses at **α = 0.05**.
#
#
# ### **Problem 4**
#
# A random sample of **20 observations** from a normal population has:
#
# * mean = 68
# * standard deviation = 6
#
# Test whether the population mean is **equal to 70** at **α = 0.05**.
#
#
# ### **Problem 5**
#
# Two brands of batteries have the following lifetimes:
#
# * Brand X: variance = 36, sample size = 14
# * Brand Y: variance = 16, sample size = 10
#
# Test whether the variability of the two brands is the same at **α = 0.05**.
#
#
# ### **Problem 6**
#
# Before and after installing a new software, the execution time (in seconds) of the same 8 programs is recorded:
#
# | Before | After |
# | ------ | ----- |
# | 12     | 10    |
# | 15     | 13    |
# | 11     | 9     |
# | 14     | 12    |
# | 13     | 11    |
# | 16     | 14    |
# | 10     | 9     |
# | 12     | 10    |
#
# Test whether the new software improves performance at **α = 0.05**.
#
# ### **Problem 7**
#
# A sample of **400 packets** has **18 defective items**.
# Test whether the defect rate is **less than 6%** at **α = 0.05**.
#
# ### **Problem 8**
#
# The following data represent exam scores from two independent classes:
#
# * Class A: n = 60, mean = 72, std = 8
# * Class B: n = 55, mean = 69, std = 9
#
# Test whether there is a significant difference at **α = 0.05**.
#
# ### **Problem 9**
#
# The correlation coefficient between height and weight for **12 individuals** is found to be **0.58**.
# Test whether the correlation is significant at **α = 0.05**.
#
# ### **Problem 10**
#
# The number of customers visiting a store on different days is recorded as:
#
# | Day      | Mon | Tue | Wed | Thu | Fri |
# | -------- | --- | --- | --- | --- | --- |
# | Observed | 48  | 52  | 50  | 46  | 54  |
#
# Test whether customer visits are **uniform across days** at **α = 0.05**.
#
# ### **Problem 11**
#
# Two training programs show the following results:
#
# * Program A: 140 successes out of 250 participants
# * Program B: 120 successes out of 230 participants
#
# Test whether the success rates differ at **α = 0.05**.
#
# ### **Problem 12**
#
# A sample of **25 items** has a mean weight of **102 grams** and standard deviation **5 grams**.
# Test whether the true mean weight is **100 grams** at **α = 0.01**.
#
# ### **Problem 13**
#
# The following table shows employee department and satisfaction level:
#
# |           | Satisfied | Not Satisfied |
# | --------- | --------- | ------------- |
# | Technical | 35        | 15            |
# | Marketing | 25        | 25            |
#
# Test whether department and satisfaction are related at **α = 0.05**.
#
# ### **Problem 14**
#
# Two samples are taken from two populations:
#
# * Sample 1: n = 18, variance = 20
# * Sample 2: n = 14, variance = 35
#
# Test whether the population variances differ significantly.
#
# ### **Problem 15**
#
# A random sample of **100 voters** shows that **62 support a policy**.
# Test whether the majority of voters support the policy at **α = 0.05**.
#
# ### **Problem 16**
#
# The following frequencies are obtained from rolling a die **90 times**:
#
# | Face | 1  | 2  | 3  | 4  | 5  | 6  |
# | ---- | -- | -- | -- | -- | -- | -- |
# | Obs  | 12 | 18 | 16 | 14 | 15 | 15 |
#
# Test whether the die is unbiased at **α = 0.05**.
#
# ### **Problem 17**
#
# The correlation coefficient between advertising cost and sales revenue for **20 observations** is **0.42**.
# Test whether this relationship is statistically significant.
#
# ### **Problem 18**
#
# Two fertilizers are tested on crop yield:
#
# * Fertilizer A: n = 10, mean = 55, std = 6
# * Fertilizer B: n = 10, mean = 60, std = 5
#
# At **α = 0.05**, determine whether fertilizer effectiveness differs.
#
# ### **Problem 19**
#
# The same students take a test before and after coaching:
#
# | Before | After |
# | ------ | ----- |
# | 45     | 55    |
# | 50     | 60    |
# | 48     | 57    |
# | 52     | 63    |
# | 46     | 56    |
# | 49     | 59    |
#
# Test whether coaching improves scores at **α = 0.05**.
#
# ### **Problem 20**
#
# A manufacturer claims that **70%** of its products meet premium quality standards.
# In a random sample of **500 products**, **330** meet the standard.
# Test the claim at **α = 0.05**.
#
# ## Output like:
#
# ```
# Problem X:
# Test:
# H0:
# H1:
# Code:
# Decision:
# ```
